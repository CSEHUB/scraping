# %%
from bs4 import BeautifulSoup
#from tabulate import tabulate
import requests
import pandas as pd
import collections

# %%
# Set website and user-agent or page will obfuscate datea
cape_website = "http://www.cape.ucsd.edu/responses/Results.aspx?Name=&CourseNumber=cse"
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

# %%
# Set up requests BeautifulSoup scraper
request = requests.get(cape_website, headers=headers)
soup = BeautifulSoup(request.content, 'html.parser')

# %%
table = soup.find_all('table')[0]

# %%
listOfValue = {}
counter = 0
tableList =  table.find_all('tbody')[0]
ClassList = tableList.find_all('tr')

# %%
for i in ClassList:
    listOfValue[i.find('a').text] = []
    
for i in ClassList:
    listOfValue[i.find('a').text].append(i.find_all('td')[2].text)

# %%
# convert unicode encoding to ascii

def convert(data):
    if isinstance(data, str):
        return str(data)
    elif isinstance(data, collections.Mapping):
        return dict(map(convert, data.items()))
    elif isinstance(data, collections.Iterable):
        return type(data)(map(convert, data))
    else:
        return data
    
listOfValue = convert(listOfValue)
listOfValue.pop('No CAPEs submitted', None)
# Out:
# ['S215', 'SP14', 'SP13']

# %%
# convert dict to string, format and replace string, convert back to dict

import json
jsonFormattedString = json.dumps(listOfValue, indent=4, sort_keys=True)
jsonFormattedString = jsonFormattedString.replace("/", "／")
jsonFormattedString = jsonFormattedString.replace(".", "．")

with open("DATA.json", "w") as outputFile:
    outputFile.write(jsonFormattedString)

jsonDict = json.loads(jsonFormattedString)

# %%
# modify databaseURL for testing

import pyrebase

config = {
  "apiKey": "apiKey",
  "authDomain": "projectId.firebaseapp.com",
  "databaseURL": "https://[DATABASE_NAME].firebaseio.com/",
  # example: "databaseURL": "https://python-to-firebase.firebaseio.com/",
  "storageBucket": "projectId.appspot.com",
}

firebase = pyrebase.initialize_app(config)
db = firebase.database()
db.update(jsonDict)
# Out:
# {'CSE 90 - Undergraduate Seminar (A)': ['SP16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'FA14',
#   'SP14',
#   'FA13',
#   'S113',
#   'FA12'],
#  'CSE 132A - Database System Principles (A)': ['WI18',
#   'FA17',
#   'S117',
#   'FA16',
#   'S116',
#   'WI16',
#   'FA15',
#   'WI15',
#   'FA14',
#   'WI14',
#   'FA13',
#   'S113',
#   'WI13',
#   'FA12'],
#  'CSE 21 - Math／Algorithm&Systems; Analys (D)': ['SP16', 'FA14'],
#  'CSE 130   - Progrmng Lang:Princpl&Paradigm; (A)': ['SP12',
#   'WI12',
#   'FA11',
#   'SP11',
#   'WI11'],
#  'CSE 3   - Fluency／Information Technology (C)': ['SP11', 'WI11'],
#  'CSE 15L - Software Tools&Techniques; Lab (B)': ['WI18',
#   'FA17',
#   'SP17',
#   'SP17',
#   'WI17',
#   'SP16',
#   'WI16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'FA14',
#   'SP14',
#   'WI14',
#   'FA13',
#   'SP13',
#   'FA07'],
#  'CSE 135   - Server-side Web Applications   (A)': ['S212',
#   'SP12',
#   'FA11',
#   'S211',
#   'SP11'],
#  'CSE 155   - Computer Vision／Machine Learng (B)': ['SP12'],
#  'CSE 143   - Microelectronic System Design  (A)': ['WI12', 'SP11'],
#  'CSE 140L  - Digital Systems Laboratory     (A)': ['S112',
#   'SP12',
#   'WI12',
#   'FA11',
#   'S111',
#   'SP11',
#   'WI11',
#   'FA10',
#   'SU10',
#   'SP10',
#   'WI10',
#   'FA09',
#   'SU09',
#   'SP09',
#   'WI09',
#   'FA08',
#   'SU08',
#   'SP08',
#   'WI08',
#   'FA07',
#   'SU07'],
#  'CSE 127 - Intro to Computer Security (A)': ['WI18',
#   'SP17',
#   'SP16',
#   'FA15',
#   'SP15',
#   'FA14',
#   'SP14',
#   'SP13',
#   'FA12'],
#  'CSE 165 - 3D User Interaction (A)': ['WI18', 'WI17', 'WI16', 'WI15', 'WI14'],
#  'CSE 12 - Basic Data Struct & OO Design (C)': ['WI18',
#   'SP17',
#   'WI17',
#   'FA16',
#   'SP16',
#   'WI16',
#   'FA15',
#   'SP15'],
#  'CSE 123 - Computer Networks (B)': ['FA16'],
#  'CSE 101 - Design & Analysis of Algorithm (B)': ['FA17',
#   'SP17',
#   'WI17',
#   'FA16',
#   'SP16',
#   'WI16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'FA13'],
#  'CSE 12   - Basic Data Struct & OO Design  (A)': ['SP12',
#   'WI12',
#   'FA11',
#   'S211',
#   'S111',
#   'SP11',
#   'WI11'],
#  'CSE 140L - Digital Systems Laboratory (A)': ['FA17',
#   'S217',
#   'WI17',
#   'FA16',
#   'S216',
#   'SP16',
#   'WI16',
#   'FA15',
#   'S115',
#   'SP15',
#   'WI15',
#   'FA14',
#   'S214',
#   'SP14',
#   'WI14',
#   'FA13',
#   'SP13',
#   'WI13',
#   'FA12'],
#  'CSE 87 - Freshman Seminar (C)': ['WI18',
#   'SP16',
#   'WI15',
#   'SP13',
#   'WI13',
#   'FA12'],
#  'CSE 3 - Fluency／Information Technology (B)': ['FA17',
#   'SP17',
#   'FA16',
#   'SP16',
#   'FA15',
#   'SP15',
#   'FA14',
#   'SP14',
#   'FA13',
#   'SP13',
#   'FA12',
#   'FA10',
#   'WI10',
#   'FA09',
#   'WI09',
#   'FA08',
#   'WI08',
#   'FA07'],
#  'CSE 87   - Freshman Seminar               (C)': ['WI12',
#   'FA11',
#   'SP11',
#   'WI11'],
#  'CSE 152 - Intro to Computer Vision (A)': ['SP17',
#   'SP16',
#   'SP15',
#   'WI14',
#   'WI13'],
#  'CSE 91 - Perspectives in CSE (D)': ['WI17', 'FA16'],
#  'CSE 120 - Princ／Computer Operating Systm (A)': ['WI18',
#   'FA17',
#   'SP17',
#   'WI17',
#   'FA16',
#   'SP16',
#   'WI16',
#   'FA15',
#   'WI15',
#   'SP14',
#   'WI14',
#   'FA13',
#   'SP13',
#   'WI13',
#   'FA10',
#   'SU10',
#   'SP10',
#   'WI10',
#   'FA09',
#   'SU09',
#   'SP09',
#   'WI09',
#   'FA08',
#   'SU08',
#   'SP08',
#   'FA07',
#   'SU07'],
#  'CSE 143 - Microelectronic System Design  (A)': ['SP09', 'WI08'],
#  'CSE 95 - Tutor Apprentice (A)': ['WI18', 'FA17', 'SP17', 'WI17', 'FA16'],
#  'CSE 86 - C++ for Java Programmers (A)': ['SP13'],
#  'CSE 91 - Perspectives in CSE (B)': ['FA17', 'WI17', 'FA16', 'FA15', 'FA12'],
#  'CSE 181 - Molecular Sequence Analysis (A)': ['WI18',
#   'WI17',
#   'WI16',
#   'WI15',
#   'WI14',
#   'WI13'],
#  'CSE 30 - Computer Organiz&Systms; Progrm (B)': ['WI18',
#   'FA17',
#   'SP17',
#   'WI17',
#   'FA16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'FA14',
#   'S214',
#   'SP14',
#   'FA13',
#   'S213',
#   'SP09',
#   'WI09'],
#  'CSE 12 - Basic Data Struct & OO Design  (A)': ['FA10',
#   'SU10',
#   'SP10',
#   'WI10',
#   'FA09',
#   'SU09',
#   'SP09',
#   'WI09',
#   'FA08',
#   'SU08',
#   'SP08',
#   'WI08',
#   'FA07'],
#  'CSE 132B  - Database System Applications   (B)': ['WI12'],
#  'CSE 8A - Intro／Computer Science: Java A (B)': ['WI14',
#   'FA13',
#   'WI13',
#   'FA12'],
#  'CSE 190   - Topics／Computer Sci & Engineer (E)': ['WI11'],
#  'CSE 131 - Compiler Construction (B)': ['FA13', 'SP13', 'WI13'],
#  'CSE 87   - Freshman Seminar               (D)': ['FA11'],
#  'CSE 8A  - Intro／Computer Science: Java A (A)': ['WI12',
#   'FA11',
#   'WI11',
#   'FA10',
#   'WI10'],
#  'CSE 12 - Basic Data Struct & OO Design (A)': ['WI18',
#   'FA17',
#   'S217',
#   'S117',
#   'SP17',
#   'WI17',
#   'FA16',
#   'S116',
#   'SP16',
#   'WI16',
#   'FA15',
#   'S215',
#   'S115',
#   'SP15',
#   'WI15',
#   'FA14',
#   'SP14',
#   'WI14',
#   'FA13',
#   'S113',
#   'S113',
#   'SP13',
#   'WI13',
#   'FA12'],
#  'CSE 15L  - Software Tools&Techniques; Lab  (D)': ['WI10'],
#  'CSE 110 - Software Engineering (C)': ['FA14'],
#  'CSE 87 - Freshman Seminar               (B)': ['FA10',
#   'WI10',
#   'FA09',
#   'SP09',
#   'FA08',
#   'FA07'],
#  'CSE 191 - Semnr／Computer Sci & Engineer (E)': ['SP16', 'SP15', 'SP14'],
#  'CSE 191 - Semnr／Computer Sci & Engineer (B)': ['WI18',
#   'FA17',
#   'SP17',
#   'WI17',
#   'FA16',
#   'SP16',
#   'WI16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'FA14',
#   'SP14',
#   'WI14',
#   'FA13',
#   'SP13'],
#  'CSE 151   - Intro to A．I． Stats Approach   (A)': ['SP12'],
#  'CSE 140   - Component&Desgn; Tech／Digtl Sys (B)': ['WI11'],
#  'CSE 8A - Intro／Computer Science: Java A (A)': ['WI14',
#   'FA13',
#   'WI13',
#   'FA12'],
#  'CSE 112 - Advanced Software Engineering (B)': ['FA13'],
#  'CSE 87 - Freshman Seminar (A)': ['WI18',
#   'FA17',
#   'SP17',
#   'WI17',
#   'SP16',
#   'WI16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'FA14',
#   'SP14',
#   'WI14',
#   'FA13',
#   'SP13',
#   'FA12'],
#  'CSE 105 - Intro／Theory of Computation (A)': ['SP17',
#   'WI17',
#   'FA16',
#   'SP16',
#   'WI16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'FA14',
#   'SP14',
#   'WI14',
#   'FA13'],
#  'CSE 107 - Intro to Modern Cryptography (A)': ['WI18',
#   'FA17',
#   'WI17',
#   'WI16',
#   'WI15',
#   'WI14'],
#  'CSE 131 - Compiler Construction          (A)': ['SP10',
#   'WI10',
#   'SP09',
#   'WI09',
#   'SP08',
#   'WI08'],
#  'CSE 145 - Embedded System Design Project (A)': ['WI18',
#   'SP17',
#   'SP16',
#   'SP15',
#   'SP14',
#   'SP13',
#   'FA12',
#   'FA12',
#   'SP10'],
#  'CSE 8A  - Intro／Computer Science: Java   (A)': ['FA09',
#   'WI09',
#   'FA08',
#   'WI08',
#   'FA07'],
#  'CSE 151 - Intro to A．I． Stats Approach (B)': ['WI17'],
#  'CSE 8AL - Intro／Computer Science:JavaLab (F)': ['WI14',
#   'FA13',
#   'WI13',
#   'FA12',
#   'FA11',
#   'WI11',
#   'FA10'],
#  'CSE 190 - Topics／Computer Sci & Engineer (E)': ['WI18',
#   'SP17',
#   'FA16',
#   'SP16',
#   'WI16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'FA14',
#   'SP14',
#   'WI13'],
#  'CSE 136 - Enterprise-class Web Applcatns (A)': ['S217',
#   'S216',
#   'SP16',
#   'S215',
#   'S214',
#   'S213',
#   'SU10'],
#  'CSE 184 - Computational Molecular Biol． (A)': ['SP14'],
#  'CSE 123   - Computer Networks              (A)': ['FA11', 'S111'],
#  'CSE 8B - Intro／Computer Sci． Java (II) (A)': ['WI18',
#   'SP17',
#   'WI17',
#   'FA16',
#   'SP16',
#   'WI16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'SP14',
#   'WI14'],
#  'CSE 15L  - Software Tools&Techniques; Lab  (C)': ['SP10',
#   'WI10',
#   'WI09',
#   'WI08'],
#  'CSE 4GS - Mathematical Beauty in Rome    (A)': ['S112',
#   'SU10',
#   'SU09',
#   'SU08'],
#  'CSE 160   - Intro to Parallel Computing    (A)': ['WI11'],
#  'CSE 135 - Server-side Web Applications   (A)': ['FA10',
#   'SU10',
#   'SP10',
#   'WI10',
#   'SP09',
#   'WI09',
#   'SU08',
#   'WI08',
#   'SU07'],
#  'CSE 8AL - Intro／Computer Science:JavaLab (G)': ['FA13',
#   'FA12',
#   'FA11',
#   'WI11',
#   'FA10'],
#  'CSE 105 - Intro／Theory of Computation (C)': ['FA16'],
#  'CSE 42 - Bldg & Programming Elct Device (B)': ['FA17'],
#  'CSE 140L - Digital Systems Laboratory (B)': ['WI18',
#   'SP17',
#   'SP16',
#   'WI16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'FA14',
#   'SP14',
#   'S213'],
#  'CSE 191   - Semnr／Computer Sci & Engineer  (A)': ['SP12', 'FA11', 'WI11'],
#  'CSE 87   - Freshman Seminar               (A)': ['SP12',
#   'WI12',
#   'FA11',
#   'SP11',
#   'WI11'],
#  'CSE 141   - Intro／Computer Architecture    (A)': ['S212',
#   'SP12',
#   'WI12',
#   'FA11',
#   'S211',
#   'SP11',
#   'WI11'],
#  'CSE 110   - Software Engineering           (A)': ['SP12',
#   'WI12',
#   'FA11',
#   'SP11',
#   'WI11'],
#  'CSE 190 - Topics／Computer Sci & Engineer (B)': ['WI18',
#   'FA17',
#   'SP17',
#   'WI17',
#   'FA16',
#   'SP16',
#   'WI16',
#   'FA15',
#   'S215',
#   'SP15',
#   'FA14',
#   'SP14',
#   'WI13',
#   'FA12',
#   'WI10'],
#  'CSE 190 - Topics／Computer Sci & Engineer (J)': ['FA17'],
#  'CSE 101 - Design & Analysis of Algorithm (A)': ['WI18',
#   'FA17',
#   'S217',
#   'S117',
#   'SP17',
#   'WI17',
#   'FA16',
#   'S116',
#   'SP16',
#   'WI16',
#   'FA15',
#   'S115',
#   'SP15',
#   'WI15',
#   'FA14',
#   'S114',
#   'SP14',
#   'WI14',
#   'FA13',
#   'S113',
#   'SP13',
#   'FA12',
#   'FA10',
#   'SU10',
#   'WI10',
#   'FA09',
#   'SU09',
#   'SP09',
#   'WI09',
#   'FA08',
#   'SU08',
#   'SP08',
#   'WI08',
#   'FA07',
#   'SU07'],
#  'CSE 141 - Intro／Computer Architecture    (A)': ['FA10',
#   'SU10',
#   'SP10',
#   'WI10',
#   'FA09',
#   'SU09',
#   'SP09',
#   'WI09',
#   'FA08',
#   'SP08',
#   'WI08',
#   'FA07',
#   'SU07'],
#  'CSE 112 - Advanced Software Engineering (A)': ['SP17',
#   'WI16',
#   'WI15',
#   'SP13',
#   'FA12'],
#  'CSE 190 - Topics／Computer Sci & Engineer (F)': ['SP16', 'SP15', 'WI15'],
#  'CSE 190   - Topics／Computer Sci & Engineer (D)': ['WI12', 'WI11'],
#  'CSE 87 - Freshman Seminar               (E)': ['WI09'],
#  'CSE 182   - Biological Databases           (A)': ['FA11', 'FA11'],
#  'CSE 15L - Software Tools&Techniques; Lab (D)': ['FA16', 'FA16', 'WI16'],
#  'CSE 8A - Intro／Computer Science: Java A (D)': ['FA13'],
#  'CSE 91 - Perspectives in CSE (C)': ['WI17', 'FA16', 'SP16', 'FA15'],
#  'CSE 12   - Basic Data Struct & OO Design  (B)': ['S112'],
#  'CSE 20 - Intro／Discrete Mathematics (B)': ['FA17',
#   'WI17',
#   'FA16',
#   'WI16',
#   'FA15',
#   'SP15',
#   'FA14',
#   'SP14',
#   'WI13'],
#  'CSE 90   - Undergraduate Seminar          (A)': ['SP12',
#   'WI12',
#   'FA11',
#   'WI11'],
#  'CSE 168 - Computer Graphics II:Rendering (A)': ['SP17',
#   'SP16',
#   'SP15',
#   'SP14',
#   'SP13',
#   'SP10',
#   'SP08'],
#  'CSE 15L  - Software Tools&Techniques; Lab  (A)': ['S112',
#   'SP12',
#   'WI12',
#   'FA11',
#   'S111',
#   'SP11',
#   'WI11',
#   'FA10',
#   'SP10',
#   'WI10',
#   'FA09',
#   'SU09',
#   'SP09',
#   'WI09',
#   'FA08',
#   'SU08',
#   'SP08',
#   'WI08'],
#  'CSE 127 - Intro to Computer Security (B)': ['FA17', 'FA16'],
#  'CSE 123 - Computer Networks              (A)': ['FA10',
#   'SP10',
#   'FA09',
#   'SP09',
#   'FA08',
#   'SP08'],
#  'CSE 191 - Semnr／Computer Sci & Engineer (D)': ['FA16',
#   'SP16',
#   'FA15',
#   'SP15',
#   'SP14',
#   'SP13'],
#  'CSE 8A - Intro／Computer Sci: Java (I) (A)': ['WI18',
#   'FA17',
#   'SP17',
#   'WI17',
#   'FA16',
#   'SP16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'FA14'],
#  'CSE 105 - Theory of Computation (A)': ['WI18', 'FA17'],
#  'CSE 8AL - Intro／Computer Science:JavaLab (C)': ['WI14',
#   'FA13',
#   'WI13',
#   'FA12',
#   'WI12',
#   'FA11',
#   'FA10',
#   'WI10',
#   'FA09',
#   'WI09',
#   'FA08',
#   'FA07'],
#  'CSE 166 - Image Processing (A)': ['FA17', 'FA16', 'FA13', 'FA12'],
#  'CSE 103 - Practical Intro／Prob & Stats (A)': ['FA17',
#   'FA16',
#   'FA15',
#   'FA14',
#   'FA13',
#   'FA12'],
#  'CSE 170 - Introduction to HCI Design (A)': ['WI15', 'WI14'],
#  'CSE 118 - Ubiquitous Computing           (A)': ['FA10', 'FA08', 'FA07'],
#  'CSE 20 - Intro／Discrete Mathematics (A)': ['WI18',
#   'FA17',
#   'SP17',
#   'WI17',
#   'FA16',
#   'SP16',
#   'WI16',
#   'FA15',
#   'S215',
#   'SP15',
#   'WI15',
#   'FA14',
#   'S114',
#   'SP14',
#   'WI14',
#   'FA13',
#   'S113',
#   'FA12'],
#  'CSE 123 - Computer Networks (A)': ['FA17',
#   'S217',
#   'WI17',
#   'SP16',
#   'FA15',
#   'SP15',
#   'FA14',
#   'FA13',
#   'SP13',
#   'FA12'],
#  'CSE 182 - Biological Databases           (A)': ['FA10',
#   'FA09',
#   'FA08',
#   'FA07'],
#  'CSE 182 - Biological Databases (A)': ['SP17',
#   'SP16',
#   'FA14',
#   'FA13',
#   'FA12'],
#  'CSE 95 - Tutor Apprentice (B)': ['FA17', 'WI17', 'FA16'],
#  'CSE 135 - Server-side Web Applications (A)': ['S216',
#   'SP16',
#   'SP15',
#   'S214',
#   'SP14',
#   'S213',
#   'SP13',
#   'FA12'],
#  'CSE 100   - Advanced Data Structures       (B)': ['WI12'],
#  'CSE 12 - Basic Data Struct & OO Design (B)': ['WI18',
#   'FA17',
#   'SP17',
#   'WI17',
#   'FA16',
#   'S216',
#   'SP16',
#   'WI16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'FA14',
#   'SP14',
#   'WI14',
#   'FA13',
#   'SP13'],
#  'CSE 190   - Topics／Computer Sci & Engineer (A)': ['FA11', 'SP11', 'WI11'],
#  'CSE 181 - Molecular Sequence Analysis    (A)': ['SP10', 'SP09', 'SP08'],
#  'CSE 110 - Software Engineering (B)': ['SP16',
#   'WI16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'SP14',
#   'WI13'],
#  'CSE 136   - Enterprise-class Web Applcatns (A)': ['S212', 'S211'],
#  'CSE 107 - Intro／Modern Cryptography      (A)': ['FA10',
#   'WI10',
#   'WI09',
#   'WI08'],
#  'CSE 15L  - Software Tools&Techniques; Lab  (B)': ['SP10',
#   'WI10',
#   'FA09',
#   'WI09',
#   'FA08',
#   'SP08',
#   'WI08'],
#  'CSE 191 - Semnr／Computer Sci & Engineer (A)': ['WI18',
#   'FA17',
#   'S317',
#   'SP17',
#   'WI17',
#   'SP16',
#   'WI16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'FA14',
#   'SP14',
#   'WI14',
#   'SP13',
#   'WI13'],
#  'CSE 7   - Intro Programming MATLAB       (A)': ['SP12', 'WI12'],
#  'CSE 105 - Theory of Computation (B)': ['WI18'],
#  'CSE 8A  - Intro／Computer Science: Java A (B)': ['FA11'],
#  'CSE 6GS - Mathematical Beauty - Rome Lab (A)': ['SU08'],
#  'CSE 118 - Ubiquitous Computing (B)': ['FA13'],
#  'CSE 132B - Database System Applications (A)': ['SP17',
#   'WI16',
#   'WI15',
#   'WI14',
#   'WI13'],
#  'CSE 11 - Intr／Computer Sci&Obj-Ori;:Java (C)': ['WI17',
#   'WI16',
#   'FA15',
#   'FA13'],
#  'CSE 121 - Oper Systms:Architc&Implementn; (A)': ['WI10', 'WI09'],
#  'CSE 21 - Math／Algorithm&Systems; Analys  (A)': ['FA10',
#   'SP10',
#   'WI10',
#   'FA09',
#   'SU09',
#   'SP09',
#   'WI09',
#   'FA08',
#   'SU08',
#   'SP08',
#   'WI08',
#   'FA07',
#   'SU07'],
#  'CSE 167 - Computer Graphics (A)': ['WI18',
#   'WI17',
#   'FA16',
#   'SP16',
#   'FA15',
#   'SP15',
#   'FA14',
#   'FA13',
#   'FA12'],
#  'CSE 8B  - Intro／Computer Science: Java   (A)': ['SP09',
#   'WI09',
#   'SP08',
#   'WI08'],
#  'CSE 107 - Intro to Modern Cryptography (B)': ['WI13'],
#  'CSE 20 - Intro／Discrete Mathematics (C)': ['SP16', 'FA15', 'SP13', 'WI13'],
#  'CSE 103 - Practical Intro／Prob & Stats (B)': ['FA17'],
#  'CSE 80 - UNIX Lab                       (A)': ['WI10', 'WI09', 'WI08'],
#  'CSE 190   - Topics／Computer Sci & Engineer (G)': ['WI12'],
#  'CSE 20 - Intro／Discrete Mathematics     (A)': ['FA10',
#   'SU10',
#   'SP10',
#   'WI10',
#   'FA09',
#   'SU09',
#   'SP09',
#   'WI09',
#   'FA08',
#   'SU08',
#   'SP08',
#   'WI08',
#   'FA07',
#   'SU07'],
#  'CSE 141 - Intro／Computer Architecture (A)': ['WI18',
#   'FA17',
#   'S217',
#   'SP17',
#   'WI17',
#   'FA16',
#   'S116',
#   'SP16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'FA14',
#   'S214',
#   'SP14',
#   'WI14',
#   'FA13',
#   'SP13',
#   'WI13',
#   'FA12'],
#  'CSE 90 - Undergraduate Seminar          (B)': ['FA10'],
#  'CSE 5A - Introduction to Programming I (A)': ['FA17',
#   'S217',
#   'S117',
#   'FA16',
#   'S216',
#   'S116',
#   'FA15',
#   'S215',
#   'S115',
#   'FA14',
#   'S214',
#   'S114',
#   'FA13',
#   'S213',
#   'S113',
#   'SP13',
#   'FA12'],
#  'CSE 132B  - Database System Applications   (A)': ['SP10', 'SP09', 'SP08'],
#  'CSE 124 - Networked Services (A)': ['FA17', 'WI17', 'WI16', 'WI15'],
#  'CSE 152 - Intro to Computer Vision       (A)': ['SP10'],
#  'CSE 190 - Topics／Computer Sci & Engineer (I)': ['FA17'],
#  'CSE 21 - Math／Algorithm&Systems; Analys (A)': ['WI18',
#   'FA17',
#   'S217',
#   'SP17',
#   'WI17',
#   'FA16',
#   'S216',
#   'WI16',
#   'FA15',
#   'S215',
#   'SP15',
#   'WI15',
#   'FA14',
#   'SP14',
#   'WI14',
#   'FA13',
#   'SP13',
#   'WI13',
#   'FA12'],
#  'CSE 3 - Fluency／Information Technology (C)': ['FA10',
#   'FA09',
#   'FA08',
#   'WI08'],
#  'CSE 190   - Topics／Computer Sci & Engineer (F)': ['WI12'],
#  'CSE 8A - Intro／Computer Science: Java A (C)': ['FA13', 'FA12'],
#  'CSE 125 - Software Sys Design & Implemnt (A)': ['SP17',
#   'SP16',
#   'SP15',
#   'SP14',
#   'SP13',
#   'SP10',
#   'SP09',
#   'SP08'],
#  'CSE 150   - Int Artif Intell:Search&Reason; (A)': ['WI12'],
#  'CSE 42 - Bldg & Programming Elct Device (A)': ['FA17'],
#  'CSE 145   - Embedded System Design Project (A)': ['WI12', 'SP11'],
#  'CSE 141 - Intro／Computer Architecture (B)': ['FA17',
#   'SP17',
#   'SP16',
#   'WI16',
#   'SP15',
#   'WI15',
#   'FA14',
#   'WI13'],
#  'CSE 140 - Component&Desgn; Tech／Digtl Sys (A)': ['WI18',
#   'FA17',
#   'S217',
#   'SP17',
#   'FA16',
#   'S216',
#   'SP16',
#   'WI16',
#   'FA15',
#   'S115',
#   'SP15',
#   'WI15',
#   'FA14',
#   'S214',
#   'SP14',
#   'WI14',
#   'FA13',
#   'S213',
#   'SP13',
#   'WI13',
#   'FA12',
#   'FA10',
#   'SU10',
#   'SP10',
#   'WI10',
#   'FA09',
#   'SU09',
#   'SP09',
#   'WI09',
#   'FA08',
#   'SU08',
#   'SP08',
#   'WI08',
#   'FA07',
#   'SU07'],
#  'CSE 141L - Project／Computer Architecture (C)': ['WI17'],
#  'CSE 150 - Int Artif Intell:Search&Reason; (A)': ['WI18',
#   'S117',
#   'SP17',
#   'FA16',
#   'S116',
#   'SP16',
#   'WI16',
#   'SP15',
#   'WI15',
#   'S214',
#   'WI14',
#   'WI13',
#   'FA12',
#   'WI10',
#   'SP09',
#   'SP08'],
#  'CSE 167   - Computer Graphics              (A)': ['FA11'],
#  'CSE 105   - Intro／Theory of Computation    (A)': ['SP12',
#   'WI12',
#   'FA11',
#   'S111',
#   'SP11',
#   'WI11'],
#  'CSE 21 - Math／Algorithm&Systems; Analys (B)': ['WI18',
#   'FA17',
#   'S217',
#   'SP17',
#   'WI17',
#   'FA16',
#   'S216',
#   'SP16',
#   'WI16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'FA14',
#   'SP14',
#   'FA13',
#   'S213',
#   'WI13'],
#  'CSE 120   - Princ／Computer Operating Systm (A)': ['S112',
#   'SP12',
#   'WI12',
#   'FA11',
#   'S111',
#   'SP11',
#   'WI11'],
#  'CSE 167 - Computer Graphics (B)': ['FA17'],
#  'CSE 130 - Progrmng Lang:Princpl&Paradigm; (B)': ['FA16', 'WI09'],
#  'CSE 8B - Intro／Computer Science: Java B (B)': ['SP13', 'WI13'],
#  'CSE 11   - Intr／Computer Sci&Obj-Ori;:Java (A)': ['S112',
#   'SP12',
#   'WI12',
#   'FA11',
#   'S111',
#   'SP11',
#   'WI11'],
#  'CSE 8AL - Intro／Computer Science:JavaLab (A)': ['WI14',
#   'FA13',
#   'WI13',
#   'FA12',
#   'WI12',
#   'FA11',
#   'WI11',
#   'FA10',
#   'WI10',
#   'FA09',
#   'WI09',
#   'FA08',
#   'WI08',
#   'FA07'],
#  'CSE 8A - Intro／Computer Sci: Java (I) (C)': ['FA17', 'FA16', 'FA15', 'FA14'],
#  'CSE 101   - Design & Analysis of Algorithm (A)': ['S112',
#   'SP12',
#   'WI12',
#   'FA11',
#   'S111',
#   'SP11',
#   'WI11'],
#  'CSE 110 - Software Engineering (A)': ['WI18',
#   'FA17',
#   'SP17',
#   'WI17',
#   'FA16',
#   'SP16',
#   'WI16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'FA14',
#   'SP14',
#   'WI14',
#   'FA13',
#   'SP13',
#   'FA12'],
#  'CSE 110 - Software Engineering           (A)': ['FA10',
#   'SP10',
#   'WI10',
#   'FA09',
#   'SU09',
#   'SP09',
#   'WI09',
#   'FA08',
#   'SU08',
#   'SP08',
#   'WI08'],
#  'CSE 112 - Advanced Software Engineering  (A)': ['FA10'],
#  'CSE 143 - Microelectronic System Design (A)': ['SP17',
#   'WI16',
#   'SP15',
#   'WI14',
#   'WI13'],
#  'CSE 191 - Semnr／Computer Sci & Engineer (C)': ['FA17',
#   'FA16',
#   'SP16',
#   'FA15',
#   'SP15',
#   'SP14',
#   'SP13'],
#  'CSE 87 - Freshman Seminar               (D)': ['WI09'],
#  'CSE 105 - Intro／Theory of Computation    (A)': ['FA10',
#   'SU10',
#   'WI10',
#   'FA09',
#   'SU09',
#   'SP09',
#   'WI09',
#   'FA08',
#   'SU08',
#   'SP08',
#   'WI08',
#   'FA07',
#   'SU07'],
#  'CSE 86   - C++ for Java Programmers       (B)': ['SP12', 'SP11'],
#  'CSE 6GS - Mathematicl Beauty in Rome-Lab (A)': ['S115',
#   'S114',
#   'S113',
#   'S112',
#   'SU10',
#   'SU09'],
#  'CSE 151 - Intro to A．I． Stats Approach (A)': ['FA17',
#   'WI17',
#   'SP16',
#   'WI16',
#   'SP15',
#   'SP14',
#   'SP13'],
#  'CSE 30 - Computer Organiz&Systms; Progrm (A)': ['WI18',
#   'FA17',
#   'S217',
#   'S117',
#   'SP17',
#   'WI17',
#   'S116',
#   'SP16',
#   'WI16',
#   'FA15',
#   'S115',
#   'SP15',
#   'WI15',
#   'FA14',
#   'SP14',
#   'WI14',
#   'FA13',
#   'SP13',
#   'WI13',
#   'FA12',
#   'FA10',
#   'SP10',
#   'WI10',
#   'FA09',
#   'SP09',
#   'WI09',
#   'FA08',
#   'SP08',
#   'WI08',
#   'FA07',
#   'SU07'],
#  'CSE 87   - Freshman Seminar               (B)': ['SP12',
#   'WI12',
#   'FA11',
#   'SP11',
#   'WI11'],
#  'CSE 153   - Cognitive Modeling             (A)': ['FA11'],
#  'CSE 160 - Intro to Parallel Computing    (A)': ['WI10', 'SU09', 'FA08'],
#  'CSE 100   - Advanced Data Structures       (A)': ['SP12',
#   'SP12',
#   'FA11',
#   'S111',
#   'SP11',
#   'WI11'],
#  'CSE 8A - Intro／Computer Sci: Java (I) (B)': ['WI18',
#   'SP17',
#   'WI17',
#   'WI16',
#   'WI15',
#   'FA14'],
#  'CSE 190 - Topics／Computer Sci & Engineer (G)': ['SP16', 'WI15'],
#  'CSE 190 - Topics／Computer Sci & Engineer (C)': ['WI18',
#   'FA17',
#   'SP17',
#   'WI17',
#   'SP16',
#   'WI16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'FA14',
#   'SP14',
#   'WI14',
#   'WI13',
#   'WI10'],
#  'CSE 30   - Computer Organiz&Systms; Progrm (A)': ['SP12',
#   'WI12',
#   'FA11',
#   'S211',
#   'SP11',
#   'WI11'],
#  'CSE 148 - Adv Processor Arch Design Proj (A)': ['SP17',
#   'SP16',
#   'SP15',
#   'SP14',
#   'SP13',
#   'SP10',
#   'SP09',
#   'SP09'],
#  'CSE 91   - Perspectives in CSE            (B)': ['WI11'],
#  'CSE 90 - Undergraduate Seminar          (A)': ['FA10',
#   'SP10',
#   'WI10',
#   'FA09',
#   'WI09'],
#  'CSE 8AL - Intro／Computer Science:JavaLab (B)': ['WI14',
#   'FA13',
#   'WI13',
#   'FA12',
#   'WI12',
#   'FA11',
#   'WI11',
#   'FA10',
#   'WI10',
#   'FA09',
#   'WI09',
#   'FA08',
#   'WI08',
#   'FA07'],
#  'CSE 8B  - Intro／Computer Science: Java B (B)': ['WI12'],
#  'CSE 30 - Computer Organiz&Systms; Progrm (C)': ['SP17',
#   'FA16',
#   'SP16',
#   'WI16',
#   'FA15',
#   'WI14'],
#  'CSE 150   - Int Artif Intell:Search&Reason; (B)': ['WI11'],
#  'CSE 140   - Component&Desgn; Tech／Digtl Sys (C)': ['WI12'],
#  'CSE 168   - Computer Graphics II:Rendering (A)': ['SP12', 'WI11'],
#  'CSE 8B - Intro／Computer Science: Java B (A)': ['SP13', 'WI13'],
#  'CSE 90   - Undergraduate Seminar          (B)': ['WI12', 'WI11'],
#  'CSE 15L - Software Tools&Techniques; Lab (A)': ['WI18',
#   'FA17',
#   'S217',
#   'SP17',
#   'SP17',
#   'WI17',
#   'FA16',
#   'FA16',
#   'S216',
#   'S116',
#   'S116',
#   'SP16',
#   'FA15',
#   'S215',
#   'S115',
#   'SP15',
#   'WI15',
#   'FA14',
#   'S114',
#   'SP14',
#   'WI14',
#   'FA13',
#   'S113',
#   'SP13',
#   'WI13',
#   'FA12',
#   'FA07'],
#  'CSE 8B - Intro／Computer Sci． Java (II) (C)': ['WI18', 'WI17'],
#  'CSE 180 - Biology Meets Computing (A)': ['FA16'],
#  'CSE 21   - Math／Algorithm&Systems; Analys  (A)': ['SP12',
#   'WI12',
#   'FA11',
#   'S211',
#   'SP11',
#   'WI11'],
#  'CSE 158 - Recommender Sys&Web; Mining (A)': ['FA17', 'WI17'],
#  'CSE 11 - Intr／Computer Sci&Obj-Ori;:Java (D)': ['FA16'],
#  'CSE 169 - Computer Animation (A)': ['WI18', 'WI17', 'SP16', 'WI15', 'WI14'],
#  'CSE 8AL - Intro／Computer Science:JavaLab (D)': ['WI14',
#   'FA13',
#   'WI13',
#   'FA12',
#   'FA11',
#   'FA10',
#   'WI10',
#   'FA09',
#   'FA08',
#   'FA07'],
#  'CSE 134B  - Web Client Languages           (A)': ['S112',
#   'S111',
#   'SU10',
#   'SU09',
#   'SU08',
#   'FA07',
#   'SU07'],
#  'CSE 112 - Software Engineerng            (A)': ['FA08'],
#  'CSE 100 - Advanced Data Structures (A)': ['WI18',
#   'FA17',
#   'SP17',
#   'WI17',
#   'FA16',
#   'S216',
#   'SP16',
#   'WI16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'FA14',
#   'SP14',
#   'WI14',
#   'FA13',
#   'S213',
#   'SP13',
#   'WI13',
#   'FA12'],
#  'CSE 4GS - Mathematical Beauty in Rome (A)': ['S115', 'S114', 'S113'],
#  'CSE 166   - Image Processing               (A)': ['FA11'],
#  'CSE 184 - Computational Molecular Biol．  (A)': ['WI10', 'WI09', 'WI08'],
#  'CSE 135 - Online Database Analytics Appl (A)': ['S217', 'SP17'],
#  'CSE 160 - Intro to Parallel Computing (A)': ['WI18',
#   'WI17',
#   'WI16',
#   'SP15',
#   'FA13',
#   'WI13'],
#  'CSE 140 - Component&Desgn; Tech／Digtl Sys (D)': ['WI17'],
#  'CSE 101 - Design & Analysis of Algorithm (C)': ['SP17',
#   'FA16',
#   'SP16',
#   'WI16',
#   'FA15',
#   'SP15',
#   'WI13'],
#  'CSE 91 - Perspectives in CSE            (A)': ['WI10',
#   'FA09',
#   'WI09',
#   'FA08',
#   'FA07'],
#  'CSE 80   - UNIX Lab                       (B)': ['WI11'],
#  'CSE 166 - Image Processing               (A)': ['FA10', 'FA09', 'FA07'],
#  'CSE 12 - Basic Data Struct & OO Design (D)': ['WI16', 'FA15', 'SP15'],
#  'CSE 100 - Advanced Data Structures (C)': ['FA17', 'FA16', 'WI16', 'FA15'],
#  'CSE 103 - Practical Intro／Prob & Stats   (A)': ['FA10',
#   'WI10',
#   'FA08',
#   'FA07'],
#  'CSE 5A  - Introduction to Programming I  (A)': ['S112',
#   'SP12',
#   'FA11',
#   'S111',
#   'SP11',
#   'FA10',
#   'SU10',
#   'SP10',
#   'FA09',
#   'SU09',
#   'SP09',
#   'FA08',
#   'SU08',
#   'SP08',
#   'FA07',
#   'SU07'],
#  'CSE 140 - Component&Desgn; Tech／Digtl Sys (B)': ['SP16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'FA14',
#   'SP14'],
#  'CSE 11 - Intr／Computer Sci&Obj-Ori;:Java (A)': ['WI18',
#   'FA17',
#   'S217',
#   'S117',
#   'SP17',
#   'WI17',
#   'S216',
#   'S116',
#   'SP16',
#   'WI16',
#   'FA15',
#   'S215',
#   'S115',
#   'SP15',
#   'WI15',
#   'FA14',
#   'S214',
#   'S114',
#   'SP14',
#   'WI14',
#   'S213',
#   'S113',
#   'SP13',
#   'WI13',
#   'FA12',
#   'FA10',
#   'SU10',
#   'SP10',
#   'WI10',
#   'FA09',
#   'SU09',
#   'SP09',
#   'WI09',
#   'FA08',
#   'SP08',
#   'WI08',
#   'FA07',
#   'SU07'],
#  'CSE 148   - Adv Processor Arch Design Proj (A)': ['SP12', 'WI11'],
#  'CSE 127 - Intro／Computer Security        (A)': ['SP10',
#   'SP09',
#   'FA08',
#   'SP08',
#   'WI08'],
#  'CSE 131 - Compiler Construction (A)': ['WI18',
#   'FA17',
#   'SP17',
#   'WI17',
#   'FA16',
#   'SP16',
#   'WI16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'FA14',
#   'SP14',
#   'WI14',
#   'SP13'],
#  'CSE 70 - Software Engineering           (A)': ['SP10',
#   'WI10',
#   'FA09',
#   'SU09',
#   'SP09',
#   'WI09',
#   'FA08',
#   'SU08',
#   'SP08',
#   'WI08'],
#  'CSE 141L - Project／Computer Architecture (B)': ['FA17',
#   'SP17',
#   'FA16',
#   'SP16',
#   'WI16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'FA14',
#   'WI14',
#   'FA13',
#   'WI13'],
#  'CSE 190 - Topics／Computer Sci & Engineer (H)': ['SP16'],
#  'CSE 100 - Advanced Data Structures (B)': ['WI18',
#   'FA17',
#   'S217',
#   'SP17',
#   'WI17',
#   'FA16',
#   'SP16',
#   'WI16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'FA14',
#   'S114',
#   'WI14',
#   'SP13'],
#  'CSE 152   - Intro to Computer Vision       (A)': ['SP12', 'SP11'],
#  'CSE 8A - Intro／Computer Sci: Java (I) (D)': ['FA17', 'FA16', 'WI16', 'FA15'],
#  'CSE 170 - Interaction Design (A)': ['WI18', 'FA17', 'WI17', 'FA16', 'WI16'],
#  'CSE 7 - Intro Programming MATLAB (A)': ['WI18',
#   'S217',
#   'SP17',
#   'WI17',
#   'S216',
#   'SP16',
#   'WI16',
#   'S115',
#   'SP15',
#   'WI15',
#   'S114',
#   'SP14',
#   'WI14',
#   'S113',
#   'SP13',
#   'WI13'],
#  'CSE 134B - Web Client Languages (A)': ['WI18',
#   'FA17',
#   'S117',
#   'WI17',
#   'S116',
#   'FA15',
#   'S115',
#   'SP15',
#   'S114',
#   'S113'],
#  'CSE 190 - Topics／Computer Sci & Engineer (D)': ['WI18',
#   'SP17',
#   'WI17',
#   'FA16',
#   'WI16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'FA14',
#   'SP14',
#   'WI14'],
#  'CSE 8AL - Intro／Computer Science:JavaLab (H)': ['FA12', 'FA11'],
#  'CSE 118   - Ubiquitous Computing           (A)': ['FA11'],
#  'CSE 141L  - Project／Computer Architecture  (A)': ['S212',
#   'SP12',
#   'WI12',
#   'FA11',
#   'S211',
#   'SP11',
#   'WI11',
#   'FA10',
#   'SU10',
#   'SP10',
#   'WI10',
#   'FA09',
#   'SU09',
#   'SP09',
#   'WI09',
#   'FA08',
#   'SP08',
#   'WI08',
#   'FA07',
#   'SU07'],
#  'CSE 91   - Perspectives in CSE            (A)': ['SP12', 'SP12', 'WI12'],
#  'CSE 87 - Freshman Seminar (D)': ['FA12'],
#  'CSE 103   - Practical Intro／Prob & Stats   (A)': ['FA11'],
#  'CSE 120 - Princ／Computer Operating Systm (B)': ['WI18',
#   'FA17',
#   'WI17',
#   'FA16',
#   'WI16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'FA14',
#   'WI14',
#   'WI13',
#   'FA12'],
#  'CSE 151 - Intro to A．I． Stats Approach   (A)': ['SP10', 'FA08', 'FA07'],
#  'CSE 169 - Computer Animation             (A)': ['WI09', 'WI08'],
#  'CSE 127   - Intro to Computer Security     (A)': ['SP12', 'FA11', 'SP11'],
#  'CSE 87 - Freshman Seminar               (C)': ['FA10',
#   'WI09',
#   'FA08',
#   'FA07'],
#  'CSE 100 - Advanced Data Structures       (A)': ['FA10',
#   'SU10',
#   'SP10',
#   'WI10',
#   'FA09',
#   'SU09',
#   'SP09',
#   'WI09',
#   'FA08',
#   'SP08',
#   'WI08',
#   'FA07',
#   'SU07'],
#  'CSE 20   - Intro／Discrete Mathematics     (A)': ['SP12',
#   'WI12',
#   'FA11',
#   'S111',
#   'SP11',
#   'WI11'],
#  'CSE 15L - Software Tools&Techniques; Lab (C)': ['WI18',
#   'FA17',
#   'SP17',
#   'SP17',
#   'WI17',
#   'FA16',
#   'FA16',
#   'SP16',
#   'WI16',
#   'FA15',
#   'SP15'],
#  'CSE 91 - Perspectives in CSE (A)': ['FA17',
#   'SP17',
#   'WI17',
#   'FA16',
#   'SP15',
#   'FA13',
#   'WI13'],
#  'CSE 80 - UNIX Lab (A)': ['S117', 'S117', 'WI13'],
#  'CSE 167 - Computer Graphics              (A)': ['FA10',
#   'FA09',
#   'FA08',
#   'SP08',
#   'FA07'],
#  'CSE 130 - Progrmng Lang:Princpl&Paradigm; (A)': ['WI18',
#   'FA17',
#   'SP17',
#   'WI17',
#   'FA16',
#   'SP16',
#   'WI16',
#   'FA15',
#   'S215',
#   'SP15',
#   'WI15',
#   'FA14',
#   'SP14',
#   'WI14',
#   'FA13',
#   'SP13',
#   'WI13',
#   'FA12',
#   'FA10',
#   'SU10',
#   'SP10',
#   'WI10',
#   'FA09',
#   'SU09',
#   'WI09',
#   'FA08',
#   'SU08',
#   'WI08',
#   'FA07',
#   'SU07'],
#  'CSE 140 - Component&Desgn; Tech／Digtl Sys (C)': ['WI17'],
#  'CSE 86 - C++ for Java Programmers       (A)': ['WI10', 'SP09', 'SP08'],
#  'CSE 191   - Semnr／Computer Sci & Engineer  (B)': ['SP12'],
#  'CSE 3   - Fluency／Information Technology (A)': ['S112',
#   'SP12',
#   'WI12',
#   'FA11',
#   'WI11'],
#  'CSE 132A  - Database System Principles     (A)': ['S112',
#   'WI12',
#   'FA11',
#   'S111',
#   'FA10',
#   'WI10',
#   'FA09',
#   'WI09',
#   'FA08',
#   'WI08',
#   'FA07'],
#  'CSE 8B  - Intro／Computer Science: Java B (A)': ['SP12',
#   'WI12',
#   'SP11',
#   'WI11',
#   'SP10',
#   'WI10'],
#  'CSE 140L - Digital Systems Laboratory (C)': ['SP17', 'WI17'],
#  'CSE 125   - Software Sys Design & Implemnt (A)': ['SP12', 'SP11'],
#  'CSE 90 - Undergraduate Seminar (B)': ['WI16', 'FA15', 'WI13'],
#  'CSE 8AL - Intro／Computer Science:JavaLab (E)': ['WI14',
#   'FA13',
#   'WI13',
#   'FA12',
#   'WI11',
#   'FA10',
#   'FA09'],
#  'CSE 141L - Project／Computer Architecture (A)': ['WI18',
#   'FA17',
#   'S217',
#   'SP17',
#   'WI17',
#   'FA16',
#   'S116',
#   'SP16',
#   'WI16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'FA14',
#   'S214',
#   'SP14',
#   'WI14',
#   'SP13',
#   'WI13',
#   'FA12'],
#  'CSE 21 - Math／Algorithm&Systems; Analys (C)': ['SP17', 'WI16', 'FA15'],
#  'CSE 181   - Molecular Sequence Analysis    (A)': ['WI12', 'WI12', 'SP11'],
#  'CSE 163 - Advanced Computer Graphics (A)': ['SP17'],
#  'CSE 20 - Intro／Discrete Mathematics (D)': ['SP13'],
#  'CSE 87 - Freshman Seminar (B)': ['SP17',
#   'FA16',
#   'SP16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'FA14',
#   'WI14',
#   'FA13',
#   'SP13',
#   'WI13',
#   'FA12'],
#  'CSE 111 - Objt． Oriented Software Design (A)': ['FA10',
#   'SP10',
#   'FA09',
#   'SP08',
#   'FA07'],
#  'CSE 190   - Topics／Computer Sci & Engineer (C)': ['WI12'],
#  'CSE 140   - Component&Desgn; Tech／Digtl Sys (A)': ['S112',
#   'SP12',
#   'FA11',
#   'S111',
#   'SP11'],
#  'CSE 107   - Intro to Modern Cryptography   (A)': ['WI12'],
#  'CSE 132A - Database System Principles (B)': ['WI17'],
#  'CSE 192 - Senior Seminar in CSE (A)': ['WI15', 'WI14', 'FA13'],
#  'CSE 87 - Freshman Seminar               (A)': ['FA10',
#   'WI10',
#   'SP09',
#   'FA08',
#   'SP08'],
#  'CSE 8B - Intro／Computer Sci． Java (II) (B)': ['WI18',
#   'FA17',
#   'WI17',
#   'SP16',
#   'WI16',
#   'SP15',
#   'WI15',
#   'SP14',
#   'WI14'],
#  'CSE 3   - Fluency／Information Technology (B)': ['WI12', 'FA11', 'WI11'],
#  'CSE 131   - Compiler Construction          (A)': ['SP12',
#   'WI12',
#   'S311',
#   'SP11',
#   'WI11'],
#  'CSE 105 - Intro／Theory of Computation (B)': ['SP17',
#   'WI17',
#   'FA16',
#   'SP16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'SP14',
#   'SP13',
#   'WI13',
#   'FA12'],
#  'CSE 118 - Ubiquitous Computing (A)': ['FA17',
#   'FA16',
#   'FA15',
#   'FA14',
#   'FA12'],
#  'CSE 190 - Topics／Computer Sci & Engineer (A)': ['WI18',
#   'FA17',
#   'S217',
#   'SP17',
#   'WI17',
#   'FA16',
#   'SP16',
#   'WI16',
#   'FA15',
#   'SP15',
#   'WI15',
#   'FA14',
#   'S114',
#   'WI14',
#   'FA13',
#   'S213',
#   'SP13',
#   'FA10',
#   'WI10',
#   'FA09',
#   'SP09',
#   'SP09',
#   'WI09',
#   'FA08',
#   'WI08'],
#  'CSE 11 - Intr／Computer Sci&Obj-Ori;:Java (B)': ['WI18',
#   'FA17',
#   'WI17',
#   'FA16',
#   'WI16',
#   'FA15',
#   'WI15',
#   'FA14',
#   'FA13'],
#  'CSE 3 - Fluency／Information Technology (A)': ['WI18',
#   'FA17',
#   'SP17',
#   'WI17',
#   'FA16',
#   'SP16',
#   'WI16',
#   'FA15',
#   'S115',
#   'SP15',
#   'WI15',
#   'FA14',
#   'S114',
#   'SP14',
#   'WI14',
#   'FA13',
#   'S113',
#   'SP13',
#   'WI13',
#   'FA12',
#   'FA10',
#   'SU10',
#   'SP10',
#   'WI10',
#   'FA09',
#   'SU09',
#   'SP09',
#   'WI09',
#   'FA08',
#   'SU08',
#   'SP08',
#   'WI08',
#   'FA07',
#   'SU07'],
#  'CSE 124 - Networked Services             (A)': ['FA10', 'FA09', 'FA07'],
#  'CSE 80   - UNIX Lab                       (A)': ['WI12']}
